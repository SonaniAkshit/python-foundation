# %% [markdown]
# ### CRUD Operations

# %%
students = {}

# %%
# CREATE

students["101"] = "Rohan"
students
# Out:
# {'101': 'Rohan'}

# %%
# Multiple Creates

students["101"] = "Keshav"
students["102"] = "kena"
students["103"] = "jemish"

# %%
students
# Out:
# {'101': 'Keshav', '102': 'kena', '103': 'jemish'}

# %%
# READ

students["101"]
# Out:
# 'Keshav'

# %%
students["9999"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 students["9999"]
#
# KeyError: '9999'

# %%
# safe
print(students.get("9999"))
# Out:
# None

# %%
# UPDATE

students["101"] = "Keshav Shrma"

print(students)
# Out:
# {'101': 'Keshav Shrma', '102': 'kena', '103': 'jemish'}

# %%
# DELETE
# using del
del students["101"]

print(students)
# Out:
# {'102': 'kena', '103': 'jemish'}

# %%
# using pop()

removed = students.pop("102")
print(removed)
print(students)
# Out:
# kena
# {'103': 'jemish'}

# %%
students = {}

# CREATE
students["101"] = "Akshit"
students["102"] = "Rahul"

print("After Create:")
print(students)

# READ
print("\nRead:")
print(students["101"])

# UPDATE
students["101"] = "Akshit Patel"

print("\nAfter Update:")
print(students)

# DELETE
del students["102"]

print("\nAfter Delete:")
print(students)
# Out:
# After Create:
# {'101': 'Akshit', '102': 'Rahul'}
#
# Read:
# Akshit
#
# After Update:
# {'101': 'Akshit Patel', '102': 'Rahul'}
#
# After Delete:
# {'101': 'Akshit Patel'}
