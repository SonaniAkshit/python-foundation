# %% [markdown]
# ### Creating Dictionary

# %%
student ={
    "name" : "gogi",
    "age" : 22
}

type(student)
# Out:
# dict

# %%
student
# Out:
# {'name': 'gogi', 'age': 22}

# %%
# empty dictionary

student = {}

# %%
student = dict()

# %%
# Accessing values

student = {
    "name" : "Rohan",
    "age" : 22
}

student["name"]
# Out:
# 'Rohan'

# %%
# Adding New Data

# Accessing values

student = {
    "name" : "Rohan",
    "age" : 22
}

student["city"] = "Surat"

student
# Out:
# {'name': 'Rohan', 'age': 22, 'city': 'Surat'}

# %%
# Updating Data

student["age"] = 20

student
# Out:
# {'name': 'Rohan', 'age': 20, 'city': 'Surat'}

# %%
# Removing Data

student.pop("age")
# Out:
# 20

# %%
student
# Out:
# {'name': 'Rohan', 'city': 'Surat'}

# %% [markdown]
# ###  Industry uses

# %%
# API Response

user = {
    "id": 1,
    "name": "Akshit",
    "email": "abc@gmail.com"
}

# Configuration Files

config = {
    "host": "localhost",
    "port": 5000
}

# %% [markdown]
# ### JSON Data

# %%
# Most JSON data becomes Python dictionaries.

{
  "name": "Akshit",
  "age": 22
}
# Out:
# {'name': 'Akshit', 'age': 22}

# %% [markdown]
# ###  ML & Data Science

# %%
# Dataset Metadata

dataset = {
    "rows": 10000,
    "columns": 20
}

# Model Parameters

params = {
    "learning_rate": 0.01,
    "epochs": 100
}

# Feature Mapping

encoding = {
    "Male": 0,
    "Female": 1
}

# Used constantly in:

# NumPy
# Pandas
# Scikit-Learn
# TensorFlow
# PyTorch

# %%
squares = {
    x: x*x
    for x in range(5)
}

squares
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
student = {
    "name": "Akshit",
    "marks": {
        "math": 90,
        "science": 95
    }
}

student
# Out:
# {'name': 'Akshit', 'marks': {'math': 90, 'science': 95}}
